# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(sys.path[0])
# Out:
# d:\internship project\multidoc-rag

# %%
import pandas as pd

queries = pd.read_csv("evaluation/benchmark_queries.csv")

print(queries.shape)
queries.head()
# Out:
# (50, 3)
#    query_id                                            query  category
# 0         1          What is the annual health check policy?        HR
# 1         2  Who is eligible for the annual health check-up?        HR
# 2         3                        What is the leave policy?        HR
# 3         4                    What is the probation period?        HR
# 4         5                      What are employee benefits?  Benefits

# %%
from src.dense_retriever import retrieve_documents

# %%
results = []

for _, row in queries.iterrows():

    query = row["query"]

    retrieved_docs = dense_retriever(query)

    ...
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       3 for _, row in queries.iterrows():
#       5     query = row["query"]
# ----> 7     retrieved_docs = dense_retriever(query)
#       9     ...
#
# NameError: name 'dense_retriever' is not defined

# %%
results.append({

    "query_id": row["query_id"],

    "query": query,

    "rank": rank,

    "score": score,

    "document": doc.metadata["source"],

    "page": doc.metadata.get("page"),

    "chunk_id": doc.metadata.get("chunk_id")

})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       1 results.append({
#       2
#       3     "query_id": row["query_id"],
#       4
#       5     "query": query,
#       6
# ----> 7     "rank": rank,
#       8
#       9     "score": score,
#      10
#      11     "document": doc.metadata["source"],
#      12
#      13     "page": doc.metadata.get("page"),
#      14
#      15     "chunk_id": doc.metadata.get("chunk_id")
#      16
#      17 })
#
# NameError: name 'rank' is not defined
